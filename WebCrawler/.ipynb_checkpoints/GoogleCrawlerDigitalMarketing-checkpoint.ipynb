# %%
import requests 
import pandas as pd
import json
from datetime import date, timedelta

# %%
keyword=input("Enter a Keyword: ")
keyword1=keyword

site_list=["quora.com","reddit.com"]

questions_list=[]

for site in site_list:
  keyword=keyword + " site:" + site
  # AIzaSyA9_pFIP87lpfV2LEbt8gdm8pualVLLIUo

  # print(keyword)

  google_url="https://www.googleapis.com/customsearch/v1?key=AIzaSyA9_pFIP87lpfV2LEbt8gdm8pualVLLIUo&cx=52b1b60a61dc24dcb"
  google_url=google_url + "&q=" +keyword

  # print("Google URL : ",google_url)

  response=requests.get(google_url)
  # print("Response : ",str(response.text))

  json_response=json.loads(response.text)
  search_time=json_response["searchInformation"]["searchTime"]
  # print("Search Time Taken is ",search_time)

  total_results=int(json_response["searchInformation"]["totalResults"])
  # print("Total Results are ",total_results)
  total_pages=round(total_results/10)

  # nextIndex=json_response["queries"]["nextPage"][0]["startIndex"]

  try:
    for item in json_response["items"]:
      title=item["title"]
      title=title.replace(" - Quora","")
      questions_list.append(title)

  except Exception as e:
    print("Exception ",e)

  keyword=keyword1

# questions_list
questions_dict={"Questions":questions_list}
df=pd.DataFrame(data=questions_dict)
df.index += 1
df
# Out:
# Enter a Keyword: Google sde projects
#                                             Questions
# 1   What sort of projects do new software engineer...
# 2   What kind of projects can a software engineer ...
# 3   How many projects are required on my resume to...
# 4   What are the best projects which can be done a...
# 5   What kind of projects will get me a job at Goo...
# 6   What kind of personal projects do companies li...
# 7   How to get a job at Facebook or Google in 6 mo...
# 8   What type of projects should I do to get inter...
# 9   I have been at Google for 7 years and still an...
# 10  Will my game development projects help me in i...
# 11  Anyone got any project matching interview at G...
# 12  What are the projects that got you hired? : r/...
# 13  What kind of side projects would get you notic...
# 14  What software engineering projects should I pu...
# 15  Google SWE 2023 - Project Matching Thread : r/...
# 16  What I learned from Software Engineering at Go...
# 17  [OFFICIAL] Excellent and Exemplary Resume Shar...
# 18  Google SDE, Facebook SDE, or Microsoft PM Inte...
# 19  People who got FAANG+ internships (or any cove...
# 20  Google SWE Intern 2023 Host Matching : r/csMajors

# %%
df.to_csv(keyword1+"_Questions.csv")
